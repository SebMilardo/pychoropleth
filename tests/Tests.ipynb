# %%
# !pip3 -q install git+http://github.com/SebMilardo/pychoropleth
# Out:
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from pychoropleth import choropleth, create_grid, add_cell_id, bounds_to_polygon
import pandas as pd
import numpy as np
import random

# %%
# create some random data
random.seed(27)
size = (1000,)
lon = np.random.normal(loc=15.11, scale=0.01, size=size)
lat = np.random.normal(loc=37.095, scale=0.1, size=size)
data = np.random.uniform(low=0, high=100, size=size)
df = pd.DataFrame(zip(lat,lon,data), columns=["latitude","longitude","data"])

# %%
bounds = bounds_to_polygon([15.0, 37.0,15.12, 37.11])
choropleth(df, grid_size=200, vmax=5, cmap="plasma", bounds=bounds, latitude="latitude", 
           longitude="longitude", tiles='cartodb_positron', column="data", crs=None, figsize=[10,10])
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
create_grid(df, grid_size=1000)
# Out:
#          latitude  longitude  data  \
# cell_id
# (0, 19)         1          1     1
# (0, 22)         1          1     1
# (0, 28)         2          2     2
# (0, 30)         1          1     1
# (0, 33)         1          1     1
# ...           ...        ...   ...
# (4, 60)         1          1     1
# (5, 30)         1          1     1
# (5, 31)         1          1     1
# (5, 47)         1          1     1
# (5, 52)         1          1     1
#
#                                                   geometry
# cell_id
# (0, 19)  POLYGON ((507040.773085962 4086494.779001401, ...
# (0, 22)  POLYGON ((507040.773085962 4089494.779001401, ...
# (0, 28)  POLYGON ((507040.773085962 4095494.779001401, ...
# (0, 30)  POLYGON ((507040.773085962 4097494.779001401, ...
# (0, 33)  POLYGON ((507040.773085962 4100494.779001401, ...
# ...                                                    ...
# (4, 60)  POLYGON ((511040.773085962 4127494.779001401, ...
# (5, 30)  POLYGON ((512040.773085962 4097494.779001401, ...
# (5, 31)  POLYGON ((512040.773085962 4098494.779001401, ...
# (5, 47)  POLYGON ((512040.773085962 4114494.779001401, ...
# (5, 52)  POLYGON ((512040.773085962 4119494.779001401, ...
#
# [220 rows x 4 columns]

# %%
import osmnx as ox

# %%
a,b = add_cell_id(df,10)

# %%
a

# %%
bounds_to_polygon([506853.9604630006,
  4101543.0040510646,
  512306.30418294383,
  4108730.3270821003])

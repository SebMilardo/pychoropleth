# %%
# !pip3 install -qe ../

# %%
import pychoropleth as pcp
import pandas as pd
import random
import numpy as np

# %%
# create some random data
random.seed(27)
lon = np.random.normal(loc=15.11, scale=0.01, size=(1000,))
lat = np.random.normal(loc=37.095, scale=0.01, size=(1000,))
data = np.random.uniform(low=0, high=100, size=(1000,))
df = pd.DataFrame(zip(lat,lon,data), columns=["latitude","longitude","data"])

# %%
pcp.choropleth(pcp.df2geo(df), grid_size=200, vmax=5, cmap="plasma")
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="600"></iframe>

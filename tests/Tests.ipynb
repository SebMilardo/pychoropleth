# %%
# !pip3 -q install git+http://github.com/SebMilardo/pychoropleth
# Out:
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from pychoropleth import choropleth, create_grid, add_cell_id, bounds_to_polygon
import pandas as pd
import numpy as np
import random

# %%
# create some random data
random.seed(27)
size = (1000,)
lon = np.random.normal(loc=15.11, scale=0.01, size=size)
lat = np.random.normal(loc=37.095, scale=0.1, size=size)
data = np.random.uniform(low=0, high=100, size=size)
df = pd.DataFrame(zip(lat,lon,data), columns=["latitude","longitude","data"])

# %%
bounds = bounds_to_polygon([15.0, 37.0,15.12, 37.11])
choropleth(df, grid_size=200, vmax=5, cmap="plasma", bounds=bounds, latitude="latitude", 
           longitude="longitude", tiles='cartodb_positron', column="data", crs=None, figsize=[10,10])
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
create_grid(df, grid_size=1000).plot()

# %%
import osmnx as ox

# %%
add_cell_id(df,10,)
# Out:
# ((506110.3183426379,
#   4067338.6246775095,
#   512617.00955625024,
#   4145251.473866306),
#        latitude  longitude       data  \
#  0    37.102190  15.113830  22.254360
#  1    37.055977  15.115884  53.256712
#  2    37.112006  15.112436   2.624625
#  3    37.013654  15.105565  95.490201
#  4    37.102067  15.099914  54.607334
#  ..         ...        ...        ...
#  995  36.982238  15.099034   3.053768
#  996  37.058243  15.116658  16.425703
#  997  37.024591  15.104800  30.960374
#  998  37.108880  15.104834  63.541471
#  999  37.110231  15.101516  84.268381
#
#                                          geometry      cell_id
#  0    POINT (510114.6157575409 4106214.759403379)  (400, 3887)
#  1    POINT (510303.3305485169 4101088.397157363)  (419, 3374)
#  2    POINT (509989.4088733063 4107303.598270024)  (387, 3996)
#  3    POINT (509391.0445403703 4096392.258079024)  (328, 2905)
#  4    POINT (508878.0616589686 4106199.784917321)  (276, 3886)
#  ..                                           ...          ...
#  995  POINT (508813.7358031436 4092906.550887195)  (270, 2556)
#  996  POINT (510371.8138513817 4101339.811253662)  (426, 3400)
#  997    POINT (509321.725455713 4097605.43132467)  (321, 3026)
#  998   POINT (509314.396599582 4106956.056463952)  (320, 3961)
#  999  POINT (509019.4140651313 4107105.547492665)  (290, 3976)
#
#  [1000 rows x 5 columns])

# %%
bounds_to_polygon([506853.9604630006,
  4101543.0040510646,
  512306.30418294383,
  4108730.3270821003])

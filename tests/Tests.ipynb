# %%
# !pip3 -q install git+http://github.com/SebMilardo/pychoropleth
# Out:
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from pychoropleth import choropleth, create_grid
import pandas as pd
import numpy as np
import random

# %%
# create some random data
random.seed(27)
size = (1000,)
lon = np.random.normal(loc=15.11, scale=0.01, size=size)
lat = np.random.normal(loc=37.095, scale=0.01, size=size)
data = np.random.uniform(low=0, high=100, size=size)
df = pd.DataFrame(zip(lat,lon,data), columns=["latitude","longitude","data"])

# %%
bounds = [[15.0, 37.0],[15.0, 37.0],[15.12, 37.11],[15.12, 37.11]]
choropleth(df, grid_size=200, vmax=5, cmap="plasma", bounds=bounds, latitude="latitude", 
           longitude="longitude", tiles='cartodb_positron', column="data", crs=None, figsize=[10,10])
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
create_grid(df, grid_size=100)
# Out:
#           latitude  longitude  data  \
# cell_id
# (0, 50)          1          1     1
# (0, 59)          1          1     1
# (1, 32)          1          1     1
# (1, 39)          1          1     1
# (5, 29)          1          1     1
# ...            ...        ...   ...
# (50, 48)         1          1     1
# (51, 43)         1          1     1
# (56, 39)         1          1     1
# (57, 41)         1          1     1
# (62, 34)         1          1     1
#
#                                                    geometry
# cell_id
# (0, 50)   POLYGON ((15.07735948501321 37.10349824946733,...
# (0, 59)   POLYGON ((15.07736773662842 37.11161108138896,...
# (1, 32)   POLYGON ((15.07846817565517 37.08727181311589,...
# (1, 39)   POLYGON ((15.0784746814429 37.09358181160302, ...
# (5, 29)   POLYGON ((15.08296596362042 37.08456446304222,...
# ...                                                     ...
# (50, 48)  POLYGON ((15.13362745123095 37.10164533725556,...
# (51, 43)  POLYGON ((15.13474486340604 37.09713693702998,...
# (56, 39)  POLYGON ((15.1403648500742 37.09352470721634, ...
# (57, 41)  POLYGON ((15.14149347617315 37.09532622166147,...
# (62, 34)  POLYGON ((15.14710778099266 37.08900939319238,...
#
# [713 rows x 4 columns]

# %%
len(df)
# Out:
# 1000

# %%
# !pip3 -q install git+http://github.com/SebMilardo/pychoropleth
# Out:
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from pychoropleth import choropleth, create_grid, add_cell_id, bounds_to_polygon
import pandas as pd
import numpy as np
import random

# %%
# create some random data
random.seed(27)
size = (1000,)
lon = np.random.normal(loc=15.11, scale=0.01, size=size)
lat = np.random.normal(loc=37.095, scale=0.1, size=size)
data = np.random.uniform(low=0, high=100, size=size)
df = pd.DataFrame(zip(lat,lon,data), columns=["latitude","longitude","data"])

# %%
bounds = bounds_to_polygon([15.0, 37.0,15.12, 37.11])
choropleth(df, grid_size=200, vmax=5, cmap="plasma", bounds=bounds, latitude="latitude", 
           longitude="longitude", tiles='cartodb_positron', column="data", crs=None, figsize=[10,10])
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
g = create_grid(df, grid_size=1000)

# %%
g.crs
# Out:
# '+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs'

# %%
import osmnx as ox

# %%
a,b = add_cell_id(df,10)

# %%
b
# Out:
#       latitude  longitude       data  \
# 0    37.206867  15.113021  36.115931
# 1    37.072006  15.117870  58.845657
# 2    37.107445  15.100328  71.620702
# 3    36.992615  15.123945  11.258880
# 4    37.136166  15.112844  19.679418
# ..         ...        ...        ...
# 995  36.958426  15.114501  27.602583
# 996  37.121115  15.118751  73.414012
# 997  37.078842  15.108286  33.955496
# 998  37.120841  15.112568  27.289280
# 999  37.234841  15.121736  35.231377
#
#                                         geometry      cell_id
# 0      POINT (15.113020733604 37.20686656027541)  (317, 4480)
# 1    POINT (15.11787007470321 37.07200642173574)  (362, 2984)
# 2    POINT (15.10032837809585 37.10744530486988)  (206, 3377)
# 3    POINT (15.12394481219377 36.99261544502542)  (418, 2103)
# 4    POINT (15.11284446977669 37.13616627693002)  (317, 3696)
# ..                                           ...          ...
# 995  POINT (15.11450139125299 36.95842575408273)  (334, 1724)
# 996  POINT (15.11875080351176 37.12111523707719)  (370, 3529)
# 997  POINT (15.10828608450921 37.07884213472624)  (277, 3060)
# 998   POINT (15.1125681586049 37.12084079212871)  (315, 3526)
# 999  POINT (15.12173610155507 37.23484137228638)  (394, 4790)
#
# [1000 rows x 5 columns]

# %%
bounds_to_polygon([506853.9604630006,
  4101543.0040510646,
  512306.30418294383,
  4108730.3270821003])

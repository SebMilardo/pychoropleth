# %%
# !pip3 -q install git+http://github.com/SebMilardo/pychoropleth
# Out:
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from pychoropleth import choropleth, create_grid, add_cell_id, bounds_to_polygon
import pandas as pd
import numpy as np
import random

# %%
# create some random data
random.seed(27)
size = (1000,)
lon = np.random.normal(loc=15.11, scale=0.01, size=size)
lat = np.random.normal(loc=37.095, scale=0.1, size=size)
data = np.random.uniform(low=0, high=100, size=size)
df = pd.DataFrame(zip(lat,lon,data), columns=["latitude","longitude","data"])

# %%
bounds = bounds_to_polygon([15.0, 37.0,15.12, 37.11])
choropleth(df, grid_size=200, vmax=5, cmap="plasma", bounds=bounds, latitude="latitude", 
           longitude="longitude", tiles='cartodb_positron', column="data", crs=None, figsize=[10,10])
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
create_grid(df, grid_size=100)

# %%
import osmnx as ox

# %%
a = bounds_to_polygon([506853.9604630006,
  4101543.0040510646,
  512306.30418294383,
  4108730.3270821003])
b,x = ox.project_geometry(a, to_latlong=True)

# %%
b

# %%
add_cell_id(df,10, bounds=bounds_to_polygon([506853.9604630006,
  4101543.0040510646,
  512306.30418294383,
  4108730.3270821003]))
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# <ipython-input-17-6bfdef3d6531> in <module>
#       2   4101543.0040510646,
#       3   512306.30418294383,
# ----> 4   4108730.3270821003]))
#
# /Volumes/Data/Repos/pychoropleth/pychoropleth/__init__.py in add_cell_id(df, grid_size, bounds, latitude, longitude, crs)
#      74 def add_cell_id(df, grid_size, bounds=None, latitude="latitude", longitude="longitude", crs=None):
#      75     gdf = df_to_gdf(df, latitude, longitude, crs)
# ---> 76     bounds, gdf = _add_cell_id(gdf, grid_size, bounds)
#      77     return bounds, gdf
#      78
#
# /Volumes/Data/Repos/pychoropleth/pychoropleth/__init__.py in _add_cell_id(gdf, grid_size, bounds)
#      47     gdf = ox.project_gdf(gdf)
#      48     crs = gdf.crs
# ---> 49     box = ox.project_geometry(bounds)[0]
#      50     bounds = box.bounds
#      51
#
# /usr/local/lib/python3.7/site-packages/osmnx/projection.py in project_geometry(geometry, crs, to_crs, to_latlong)
#      51     gdf['geometry'] = None
#      52     gdf.loc[0, 'geometry'] = geometry
# ---> 53     gdf_proj = project_gdf(gdf, to_crs=to_crs, to_latlong=to_latlong)
#      54     geometry_proj = gdf_proj['geometry'].iloc[0]
#      55     return geometry_proj, gdf_proj.crs
#
# /usr/local/lib/python3.7/site-packages/osmnx/projection.py in project_gdf(gdf, to_crs, to_latlong)
#     113
#     114             # project the GeoDataFrame to the UTM CRS
# --> 115             projected_gdf = gdf.to_crs(utm_crs)
#     116             log('Projected the GeoDataFrame "{}" to UTM-{} in {:,.2f} seconds'.format(gdf.gdf_name, utm_zone, time.time()-start_time))
#     117
#
# /usr/local/lib/python3.7/site-packages/geopandas/geodataframe.py in to_crs(self, crs, epsg, inplace)
#     457         else:
#     458             df = self.copy()
# --> 459         geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#     460         df.geometry = geom
#     461         df.crs = geom.crs
#
# /usr/local/lib/python3.7/site-packages/geopandas/geoseries.py in to_crs(self, crs, epsg)
#     303                 raise TypeError('Must set either crs or epsg for output.')
#     304         proj_in = pyproj.Proj(self.crs, preserve_units=True)
# --> 305         proj_out = pyproj.Proj(crs, preserve_units=True)
#     306         if _PYPROJ2:
#     307             transformer = pyproj.Transformer.from_proj(proj_in, proj_out)
#
# /usr/local/lib/python3.7/site-packages/pyproj/proj.py in __init__(self, projparams, preserve_units, **kwargs)
#     293         '116.366 39.867'
#     294         """
# --> 295         self.crs = CRS.from_user_input(projparams if projparams is not None else kwargs)
#     296         # make sure units are meters if preserve_units is False.
#     297         if not preserve_units and "foot" in self.crs.axis_info[0].unit_name:
#
# /usr/local/lib/python3.7/site-packages/pyproj/crs.py in from_user_input(cls, value)
#     224             return cls(**value)
#     225         elif isinstance(value, string_types):
# --> 226             return cls.from_string(value)
#     227         elif hasattr(value, "to_wkt"):
#     228             return cls(value.to_wkt())
#
# /usr/local/lib/python3.7/site-packages/pyproj/crs.py in from_string(cls, proj_string)
#     200             else:
#     201                 return cls(**val)
# --> 202         return cls(proj_string)
#     203
#     204     @classmethod
#
# /usr/local/lib/python3.7/site-packages/pyproj/crs.py in __init__(self, projparams, **kwargs)
#     144         # on case-insensitive filesystems).
#     145         projstring = projstring.replace("+init=EPSG", "+init=epsg").strip()
# --> 146         super(CRS, self).__init__(projstring)
#     147
#     148     @classmethod
#
# pyproj/_crs.pyx in pyproj._crs._CRS.__init__()
#
# CRSError: Invalid projection: +proj=utm +zone=84961 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs: (Internal Proj Error: proj_create: Error -35: invalid UTM zone number)

# %%
bounds_to_polygon([506853.9604630006,
  4101543.0040510646,
  512306.30418294383,
  4108730.3270821003])

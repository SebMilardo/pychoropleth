# %%
# !pip3 -q install git+http://github.com/SebMilardo/pychoropleth
# Out:
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from pychoropleth import choropleth, create_grid, add_cell_id
import pandas as pd
import numpy as np
import random

# %%
# create some random data
random.seed(27)
size = (1000,)
lon = np.random.normal(loc=15.11, scale=0.01, size=size)
lat = np.random.normal(loc=37.095, scale=0.1, size=size)
data = np.random.uniform(low=0, high=100, size=size)
df = pd.DataFrame(zip(lat,lon,data), columns=["latitude","longitude","data"])

# %%
bounds = [[15.0, 37.0],[15.0, 37.0],[15.12, 37.11],[15.12, 37.11]]
choropleth(df, grid_size=200, vmax=5, cmap="plasma", bounds=bounds, latitude="latitude", 
           longitude="longitude", tiles='cartodb_positron', column="data", crs=None, figsize=[10,10])
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
create_grid(df, grid_size=100)
# Out:
#           latitude  longitude  data  \
# cell_id
# (0, 25)          1          1     1
# (3, 36)          1          1     1
# (4, 43)          1          1     1
# (6, 55)          1          1     1
# (6, 57)          1          1     1
# ...            ...        ...   ...
# (51, 42)         1          1     1
# (51, 43)         1          1     1
# (51, 55)         1          1     1
# (53, 47)         1          1     1
# (54, 46)         1          1     1
#
#                                                    geometry
# cell_id
# (0, 25)   POLYGON ((15.07711503879161 37.08264238518942,...
# (3, 36)   POLYGON ((15.08050087128724 37.09255585868411,...
# (4, 43)   POLYGON ((15.08163290217921 37.09886508187135,...
# (6, 55)   POLYGON ((15.08389554145722 37.10968062462119,...
# (6, 57)   POLYGON ((15.0838975302125 37.11148347494652, ...
# ...                                                     ...
# (51, 42)  POLYGON ((15.13452294856383 37.09791545030556,...
# (51, 43)  POLYGON ((15.13452454229063 37.09881687580747,...
# (51, 55)  POLYGON ((15.1345436725449 37.10963397111132, ...
# (53, 47)  POLYGON ((15.13678172962635 37.10242000148917,...
# (54, 46)  POLYGON ((15.13790550136428 37.10151727316582,...
#
# [711 rows x 4 columns]

# %%
add_cell_id(df,10, bounds=[506853.9604630006,
  4101543.0040510646,
  512306.30418294383,
  4108730.3270821003])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/shapely/speedups/_speedups.pyx in shapely.speedups._speedups.geos_linearring_from_py()
#
# AttributeError: 'list' object has no attribute '__array_interface__'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a74ed4a1092c> in <module>
#       2   4101543.0040510646,
#       3   512306.30418294383,
# ----> 4   4108730.3270821003])
#
# /Volumes/Data/Repos/pychoropleth/pychoropleth/__init__.py in add_cell_id(df, grid_size, bounds, latitude, longitude, crs)
#      66 def add_cell_id(df, grid_size, bounds=None, latitude="latitude", longitude="longitude", crs=None):
#      67     gdf = df_to_gdf(df, latitude, longitude, crs)
# ---> 68     bounds, gdf = _add_cell_id(gdf, grid_size, bounds)
#      69     return bounds, gdf
#      70
#
# /Volumes/Data/Repos/pychoropleth/pychoropleth/__init__.py in _add_cell_id(gdf, grid_size, bounds)
#      47     gdf = ox.project_gdf(gdf)
#      48     crs = gdf.crs
# ---> 49     box = ox.project_geometry(Polygon(bounds))[0]
#      50     bounds = box.bounds
#      51
#
# /usr/local/lib/python3.7/site-packages/shapely/geometry/polygon.py in __init__(self, shell, holes)
#     238
#     239         if shell is not None:
# --> 240             ret = geos_polygon_from_py(shell, holes)
#     241             if ret is not None:
#     242                 self._geom, self._ndim = ret
#
# /usr/local/lib/python3.7/site-packages/shapely/geometry/polygon.py in geos_polygon_from_py(shell, holes)
#     492
#     493     if shell is not None:
# --> 494         ret = geos_linearring_from_py(shell)
#     495         if ret is None:
#     496             return None
#
# /usr/local/lib/python3.7/site-packages/shapely/speedups/_speedups.pyx in shapely.speedups._speedups.geos_linearring_from_py()
#
# TypeError: object of type 'float' has no len()

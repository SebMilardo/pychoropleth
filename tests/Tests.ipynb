# %%
# !pip3 -q install git+http://github.com/SebMilardo/pychoropleth
# Out:
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from pychoropleth import choropleth, create_grid, add_cell_id
import pandas as pd
import numpy as np
import random

# %%
# create some random data
random.seed(27)
size = (1000,)
lon = np.random.normal(loc=15.11, scale=0.01, size=size)
lat = np.random.normal(loc=37.095, scale=0.01, size=size)
data = np.random.uniform(low=0, high=100, size=size)
df = pd.DataFrame(zip(lat,lon,data), columns=["latitude","longitude","data"])

# %%
bounds = [[15.0, 37.0],[15.0, 37.0],[15.12, 37.11],[15.12, 37.11]]
choropleth(df, grid_size=200, vmax=5, cmap="plasma", bounds=bounds, latitude="latitude", 
           longitude="longitude", tiles='cartodb_positron', column="data", crs=None, figsize=[10,10])
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
create_grid(df, grid_size=100)
# Out:
#           latitude  longitude  data  \
# cell_id
# (0, 40)          1          1     1
# (4, 45)          1          1     1
# (5, 18)          1          1     1
# (6, 13)          1          1     1
# (7, 19)          1          1     1
# ...            ...        ...   ...
# (50, 46)         1          1     1
# (50, 52)         1          1     1
# (51, 33)         1          1     1
# (54, 40)         1          1     1
# (58, 43)         1          1     1
#
#                                                    geometry
# cell_id
# (0, 40)   POLYGON ((15.07782208557493 37.09964095484223,...
# (4, 45)   POLYGON ((15.08232842993888 37.10414504785501,...
# (5, 18)   POLYGON ((15.08342717900062 37.07980570489458,...
# (6, 13)   POLYGON ((15.08454724783073 37.07529775728142,...
# (7, 19)   POLYGON ((15.08567834020688 37.08070553054441,...
# ...                                                     ...
# (50, 46)  POLYGON ((15.13409989792317 37.10499922753486,...
# (50, 52)  POLYGON ((15.134109433719 37.11040777210189, 1...
# (51, 33)  POLYGON ((15.13520451647502 37.09327941975369,...
# (54, 40)  POLYGON ((15.13859182034851 37.09958550245705,...
# (58, 43)  POLYGON ((15.14309836117214 37.10228443036738,...
#
# [701 rows x 4 columns]

# %%
add_cell_id(df,10, latitude=)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fb1ba6eeac88> in <module>
# ----> 1 add_cell_id(df,10)
#
# /Volumes/Data/Repos/pychoropleth/pychoropleth/__init__.py in add_cell_id(df, grid_size, bounds)
#      65
#      66 def add_cell_id(df, grid_size, bounds=None):
# ---> 67     gdf = df_to_gdf(df, latitude, longitude, crs)
#      68     bounds, gdf = _add_cell_id(gdf, grid_size, bounds)
#      69     return bounds, gdf
#
# NameError: name 'latitude' is not defined
